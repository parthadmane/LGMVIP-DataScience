# %% [markdown]
# # LETSGROWMORE Virtual Data Science Internship
# **Task 3 : Image to Pencil Sketch with Python**

# %%
import numpy as np
import cv2
from PIL import Image
from IPython.display import display

# %%
img  =  cv2.imread("/content/1.jpg")
img = cv2.resize(img,(200,300))
rgb_img =  cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
display(Image.fromarray(rgb_img))
# Out:
# <PIL.Image.Image image mode=RGB size=200x300 at 0x7FBD4FACDA10>

# %%
greyscale_img =  cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(greyscale_img))
# Out:
# <PIL.Image.Image image mode=L size=200x300 at 0x7FBD4FA75590>

# %%
neg_img = cv2.bitwise_not(greyscale_img)
display(Image.fromarray(neg_img))
# Out:
# <PIL.Image.Image image mode=L size=200x300 at 0x7FBD4FA801D0>

# %%
smooth_img = cv2.GaussianBlur(neg_img, (5,5), 0, 0)
display(Image.fromarray(smooth_img))
# Out:
# <PIL.Image.Image image mode=L size=200x300 at 0x7FBD4FA80DD0>

# %%
sketch_img = 255 - smooth_img
sketch = cv2.divide(greyscale_img, sketch_img, scale=250.0)
display(Image.fromarray(sketch))
# Out:
# <PIL.Image.Image image mode=L size=200x300 at 0x7FBD4EA069D0>

# %% [markdown]
# Comparision between Original Image and Pencil Sketch

# %%
rgb_img =  cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
display(Image.fromarray(rgb_img))
display(Image.fromarray(sketch))
# Out:
# <PIL.Image.Image image mode=RGB size=200x300 at 0x7FBD4FA80090>
# <PIL.Image.Image image mode=L size=200x300 at 0x7FBD4EA0BF50>
